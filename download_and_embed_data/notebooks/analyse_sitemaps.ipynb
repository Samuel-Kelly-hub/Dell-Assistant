# %%
import json

import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Read in sitemaps
#
# Works for large numbers of sitemaps, even though I currently only have 2, in case I want to expand the scope of the project

# %%
DATA_DIR = Path.cwd().parent.parent / "data"
filepaths = sorted(DATA_DIR.glob("dell_sitemaps_success_*.json"))
print("Number of files:", len(filepaths))
sitemaps = []
for idx, filepath in enumerate(filepaths, start=1):
    with open(filepath, "r", encoding="utf-8") as f:
         sitemaps.append(json.load(f))

# %%
for idx, sitemap in enumerate(sitemaps):
    print(f"length of sitemaps[{idx}]: {len(sitemap):,}")
    print(f"number of links in sitemaps[{idx}]: {sum(len(v) for v in sitemap.values()):,}")
# Out:
# length of sitemaps[0]: 2
# number of links in sitemaps[0]: 89,862
# length of sitemaps[1]: 2,587
# number of links in sitemaps[1]: 532,760

# %% [markdown]
# ### sitemaps[0]

# %%
next(reversed(sitemaps[0].values()))[:100]
# Out:
# ['https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_tr-tr.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_ru-rs.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_ko-kr.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_zh-tw.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_ja-jp.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-area51-alx_owners-manual_zh-cn.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_de-de.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_reference%20guide_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_en-us.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_owner's%20manual_en-us.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_es-mx.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_reference%20guide_sl-si.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_setup%20guide_sl-si.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_user's%20guide_sl-si.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_user's%20guide2_sl-si.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics_accessories/esuprt_electronics_accessories_monitors/alienware-25-gaming-monitor-aw2518hf_user's-guide_sr-yu.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_reference%20guide_sr-yu.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_setup%20guide_sr-yu.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_user's%20guide_sr-yu.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-25-gaming-monitor-aw2518hf_user's%20guide2_sr-yu.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_reference_guide_ru-rs.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_setup-guide_he-il.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_user's-guide_he-il.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_reference_guide_he-il.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_setup-guide_ar-ae.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_user's-guide_ar-ae.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_reference_guide_ar-ae.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_setup-guide_th-th.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_user's-guide_th-th.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_reference_guide_th-th.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_reference%20guide_in-id.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_in-id.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_da-dk.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_de-de.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_reference%20guide_en-us.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_owner's%20manual_en-us.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_es-mx.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_fr-fr.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_it-it.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_nl-nl.pdf',
#  'https://downloads.dell.com/manuals/common/pc-foc640_upg_en-us.pdf',
#  'https://downloads.dell.com/manuals/common/brocade-300_administrator%20guide8_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1450-projector_setup%20guide_po-pl.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_projector/dell-1200mp_owner's%20manual_sv-se.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_setup%20guide_in-id.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_pt-pt.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_reference%20guide_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_display/dell-1708fp_setup%20guide_pt-br.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_user's%20guide_in-id.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_setup%20guide_cs-cz.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_user's%20guide_cs-cz.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_setup%20guide_da-dk.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_projector/dell-1430x_user's%20guide_da-dk.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_setup%20guide_de-de.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_projector/dell-1430x_user's%20guide_de-de.pdf",
#  'https://downloads.dell.com/manuals/common/dell-1420x_setup%20guide_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_reference%20guide_en-us.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_user's%20guide_en-us.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1430x_setup%20guide_es-mx.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_fi-fi.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_projector/dell-1410x_user's%20guide_sv-se.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_gr-gr.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_ru-rs.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_ar-ae.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_th-th.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_ko-kr.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_ja-jp.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_zh-cn.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1410x_user's%20guide_zh-hk.pdf",
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1510x_user's%20guide_in-id.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_es-mx.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_user's%20guide_es-mx.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_fr-fr.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_user's%20guide_fr-fr.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_it-it.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_user's%20guide_it-it.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_nl-nl.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_user's%20guide_nl-nl.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_no-no.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics/esuprt_projector/dell-1420x_user's%20guide_no-no.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_projector/dell-1420x_setup%20guide_po-pl.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_fr-fr.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_electronics_accessories/esuprt_electronics_accessories_monitors/alienware-25-gaming-monitor-aw2518hf_user's-guide_vi-vn.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_display_projector/esuprt_display/alienware-34-monitor-aw3418hw_setup-guide_ko-kr.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-17_setup%20guide_no-no.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_po-pl.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_ru-rs.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_ar-ae.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_ja-jp.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_zh-cn.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_laptop/esuprt_alienware_laptops/alienware-18_setup%20guide_zh-hk.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_setup-guide_da-dk.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_reference%20guide_da-dk.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_reference%20guide_de-de.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_setup%20guide_en-us.pdf',
#  "https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_owner's%20manual_en-us.pdf",
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_reference%20guide_en-us.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_setup%20guide_es-mx.pdf',
#  'https://downloads.dell.com/manuals/all-products/esuprt_desktop/esuprt_alienware_dsk/alienware-alpha_reference%20guide_es-mx.pdf']

# %% [markdown]
# On visual inspection, sitemaps[0] appears to have a variety of PDF documents all in different languages, with the English documents in en-us

# %%
print(f"Number of sitemaps with en-uk: {len([url for url_list in sitemaps[0].values() for url in url_list if "en-uk" in url]):,}")
print(f"Number of sitemaps with en-us: {len([url for url_list in sitemaps[0].values() for url in url_list if "en-us" in url]):,}")
print(f"Total sitemaps: {len(sitemaps[0].values()):,}")
# Out:
# Number of sitemaps with en-uk: 0
# Number of sitemaps with en-us: 12,773
# Total sitemaps: 2

# %%
pd.Series({name: sum("en-us" in url for url in url_list) for name, url_list in sitemaps[0].items()})
# Out:
# https://www.dell.com/downloads-dell-pdfs-sitemap-0002.xml.gz    6105
# https://www.dell.com/downloads-dell-pdfs-sitemap-0001.xml.gz    6668
# dtype: int64

# %%
pd.Series({name: sum("en-us" in url and "pdf" in url for url in url_list) for name, url_list in sitemaps[0].items()})
# Out:
# https://www.dell.com/downloads-dell-pdfs-sitemap-0002.xml.gz    6105
# https://www.dell.com/downloads-dell-pdfs-sitemap-0001.xml.gz    6668
# dtype: int64

# %% [markdown]
# All documents in sitemaps[0] that we want to scrape are PDFs

# %% [markdown]
# ### sitemaps[1]

# %%
next(reversed(sitemaps[1].values()))
# Out:
# ['https://www.dell.com/support/home/en-us/drivers/supportedos/xps-430',
#  'https://www.dell.com/support/home/en
drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mt/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mu/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mv/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mw/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-na/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ng/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-np/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-om/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-pg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ph/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-pk/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-pr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-pw/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-qa/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-rw/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-sa/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-si/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-sl/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-so/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-sr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-sz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-tc/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-th/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-tt/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-tz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ug/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-vc/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-vg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-vi/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-vn/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-vu/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ws/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ye/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-yu/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-za/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-zm/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-zw/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-ar/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-bo/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-cl/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-co/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-cr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-do/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-ec/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-gt/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-hn/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-mx/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-ni/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-pa/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-pe/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-pr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-py/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-sv/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-uy/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/es-ve/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fi-fi/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-bf/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-bi/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-bj/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-cd/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-cf/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-cg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-ci/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-dj/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-dz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-ga/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-gf/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-gn/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-gq/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-km/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-lu/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-ma/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-mg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-ml/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-mq/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-mr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-nc/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-ne/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-pf/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-re/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-sc/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-sn/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-td/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-tg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-tn/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-yt/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/hu-hu/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/pt-pt/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ro-md/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ro-ro/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-am/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-az/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-ge/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-kg/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-kz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-tj/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-tm/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/ru-uz/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/sk-sk/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/tr-tr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/uk-ua/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-ck/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-fm/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-me/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-mp/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-nr/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-sb/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-tl/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-to/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/en-tv/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-cm/drivers/supportedos/xps-one',
#  'https://www.dell.com/support/home/fr-gp/drivers/supportedos/xps-one']

# %% [markdown]
# sitemaps[1] appears to have a different support page in each of its leaf sitemap, with each sitemap containing many versions of this same page in different languages.
#
# There are several different English pages, with British English ones containing en-uk

# %%
print(f"Number of sitemaps with en-uk: {len([url for url_list in sitemaps[1].values() for url in url_list if "en-uk" in url]):,}")
print(f"Number of sitemaps with en-us: {len([url for url_list in sitemaps[1].values() for url in url_list if "en-us" in url]):,}")
print(f"Total sitemaps: {len(sitemaps[1].values()):,}")
# Out:
# Number of sitemaps with en-uk: 2,624
# Number of sitemaps with en-us: 2,625
# Total sitemaps: 2,587

# %%
pd.Series({name: sum("en-uk" in url for url in url_list) for name, url_list in sitemaps[1].items()}).value_counts()
# Out:
# 1    2550
# 2      37
# Name: count, dtype: int64

# %% [markdown]
# Every leaf sitemap has at least 1 page in en-uk

# %% [markdown]
# ### Combining the URLs from the sitemaps

# %%
urls_to_scrape = pd.Series(
    [url for url_list in sitemaps[0].values() for url in url_list if "en-us" in url] +
    [url for url_list in sitemaps[1].values() for url in url_list if "en-uk" in url],
    name="url"
)


print(f"Total URLs: {len(urls_to_scrape):,}")
print(f"Unique URLs: {urls_to_scrape.nunique():,}")

urls_to_scrape = urls_to_scrape.drop_duplicates()
print(f"Final URLs to scrape: {len(urls_to_scrape):,}")
# Out:
# Total URLs: 15,397
# Unique URLs: 13,817
# Final URLs to scrape: 13,817

# %%
print(f"The longest url string contains {len(urls_to_scrape.loc[urls_to_scrape.str.len().idxmax()])} characters")
# Out:
# The longest url string contains 217 characters

# %%
urls_to_scrape.to_csv(DATA_DIR / "urls_to_scrape.csv", index=False)
